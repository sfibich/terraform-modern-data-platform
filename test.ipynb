# %%
dbutils.fs.ls("/mnt/example")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [FileInfo(path=&#39;dbfs:/mnt/example/example.csv&#39;, name=&#39;example.csv&#39;, size=194)]</div>

# %%
df = spark.read.option("header", "true").csv("/mnt/example/example.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+-------------------+--------------------+-------------+----+----+----+
# PolicyNumber|PolicyEffectiveDate|PolicyExpirationDate|PremiumAmount| _c4| _c5| _c6|
# +------------+-------------------+--------------------+-------------+----+----+----+
#     Asdf1234|           1/1/2020|          12/31/2020|      1200.00|null|null|null|
#      Asdf123|           1/2/2020|            1/1/2021|      2400.00|null|null|null|
# 44545411asdf|           1/3/2021|            1/3/2022|      3600.00|null|null|null|
# +------------+-------------------+--------------------+-------------+----+----+----+
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
